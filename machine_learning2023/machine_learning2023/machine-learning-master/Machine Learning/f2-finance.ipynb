# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# seaborn是基于matplotlib的一个可视化的库 是在matplotlib的基础上进行的更加高级的封装 是作图变得更加容易
# 它不需要了解大量底层参数就能使得图形变得更加精致 兼容numpy和pandas的数据结构，进而在很大程度上完成数据可视化
plt.style.use('seaborn')

# %%
data = pd.read_csv('data.csv',index_col=0,parse_dates=True)
data.head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-01        NaN     NaN     NaN     NaN     NaN     NaN      NaN    NaN
# 2010-01-04  30.572827  30.950   20.88  133.90  173.08  113.33  1132.99  20.04
# 2010-01-05  30.625684  30.960   20.87  134.69  176.14  113.63  1136.52  19.35
# 2010-01-06  30.138541  30.770   20.80  132.25  174.26  113.71  1137.14  19.16
# 2010-01-07  30.082827  30.452   20.60  130.00  177.67  114.19  1141.69  19.06
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-01  1.4323  1096.35    NaN     NaN
# 2010-01-04  1.4411  1120.00  47.71  109.80
# 2010-01-05  1.4368  1118.65  48.17  109.70
# 2010-01-06  1.4412  1138.50  49.34  111.51
# 2010-01-07  1.4318  1131.90  49.10  110.82

# %%
data.plot(figsize=(10,12),subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
# pct_change表示当前元素与先前元素的相差百分比
# kind='bar',color=['g','r','b']表示绘制柱状图，有g(GREEN),r(RED),b(BLUE)
data.pct_change().mean().plot(kind='bar',color=['g','r','b'])
# Out:
# <AxesSubplot:>

# %%
# data.shift（1)表示将数据向下移动一位
rets = np.log(data / data.shift(1))

# %%
# 每一天 相对于 初始日期的 收益率
# cumsum函数用于计算各行累加值
pr = np.cumsum(rets).apply(np.exp)

# %%
# 绘图，设置长为10，宽为6
pr.plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 投资分析
# 1. 双均线分析策略
# 2. 短期/长期均线分析
# 3. 黄金交叉/死亡交叉

# %%
windows = 50

# %%
# 1. 筛选出 APPLE 的股票曲线

apple = data[['AAPL.O']].dropna()

# %%
# 2. 双均线分析
apple['short'] = apple['AAPL.O'].rolling(window=50).mean()
apple['long'] = apple['AAPL.O'].rolling(window=250).mean()

# %%
apple[['short','long']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apple['position'] = np.where(apple['short'] > apple['long'],1,-1)

# %%
apple[['short','long','position']].plot(figsize=(12,5),secondary_y='position')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 双均线策略
# 1. 执行策略的收益率
# 2. 最佳策略

# %%
df = apple[['AAPL.O','position']].copy

# %%
# 收益率
df['rets'] = np.log(df['APPL.O']/df['AAPL.O'].shift(1))
# 策略

df['stategy'] = df['position'].shift(1) * df['rets']
df.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <module>
#       1 # 收益率
# ----> 2 df['rets'] = np.log(df['APPL.O']/df['AAPL.O'].shift(1))
#       3 # 策略
#       5 df['stategy'] = df['position'].shift(1) * df['rets']
#
# TypeError: 'method' object is not subscriptable

# %%
np.exp(df[['rets','position']].sum())

# %%
apple['postion'] = np.where(apple['short'] > apple['long'],1,-1)
