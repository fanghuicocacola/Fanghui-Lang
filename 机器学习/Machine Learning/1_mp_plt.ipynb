# %%
import matplotlib.pyplot as plt
import numpy as np
fig, axes = plt.subplots(2,1)
plt.subplot(2,1,1)

x=np.linspace(-10,10,100)
y=np.sin(x)

plt.plot(x,y, marker='o')

plt.subplot(2,1,2)

a = np.arange(10)
plt.plot(a, a * 1.5, a, a*2.5, a, a* 3.5, a, a*4.5)
# Out:
# [<matplotlib.lines.Line2D at 0x19d4fec4d48>,
#  <matplotlib.lines.Line2D at 0x19d52000ac8>,
#  <matplotlib.lines.Line2D at 0x19d52000cc8>,
#  <matplotlib.lines.Line2D at 0x19d52000ec8>]
